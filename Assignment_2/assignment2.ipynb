# %%
import nltk
import json
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from bs4 import BeautifulSoup
import re
from argparse import ArgumentParser
from collections import defaultdict
import math
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm

# %%
#removes stop words from a given string
def remove_stopwords(text, lst_stopwords):
    words = text.split()
    filtered_sentence = [w for w in words if not w.lower() in lst_stopwords]
    clean_text = ' '.join(filtered_sentence).strip()
    return clean_text

# %%
#
def preprocess_answers(answer_dict):
    stop_words = stopwords.words('english')
    for item in answer_dict:
        text = item['Text']
        text = remove_stopwords(text, stop_words)
        text = text.lower()
        text = remove_tags(BeautifulSoup(text, "html.parser"))
        text = re.sub(r'[^\w\s]', '',text)
        
        item['Text'] = text
    return answer_dict

# %%
def remove_tags(soup):
    for data in soup:
        if hasattr(data, 'decompose'):
            data.decompose()
    return ' '.join(soup.stripped_strings)

# %%
def preprocess_query_remove_html(data):
    for item in data:
        text = item['Text']
        #print(item['Id'])
        text = remove_tags(BeautifulSoup(text, "html.parser"))
        item['Text'] = text
    print("Tags removed")

# %%
def tokenize_doc(doc):
    #turn text into list of tokens
    text = doc['Text']
    text = text.split()
    return text

# %%
def doc2vec(doc):    
    text = doc['Text']
    text = text.split()
    return {doc['Id'] : text}

# %%
#returns doc id : string representation of the question.
def answer_reduce(data):
    answers = {}
    for doc in data:
        doc2vec(doc)
        answers.update(doc2vec(doc))
    return answers

# %%
def generate_corpus(answers):
    corpus = []
    #generates the set of all words in the search space
    for item in answers:
        corpus += tokenize_doc(item)
    return set(corpus)

# %%
def index_answers(corpus, docs):
    inverted_index = {term: [] for term in corpus}
    
    for doc_id, terms in docs.items():
        for term in terms:
            if term in corpus:
                inverted_index[term].append(doc_id)
            
                
    return inverted_index

# %%
def idf(index,term,docs):
    doc_freq = len(index[term])
    return math.log(doc_freq+1/len(docs)+1)

# %%
def tf(term, doc):
    freq = doc.count(term)
    doc_len = len(doc)
    return freq / doc_len if doc_len > 0 else 0

# %%
def tf_idf(index,term,docs,doc):
    if term in doc:
        return tf(term,doc)*idf(index,term,docs)
    else:
        return 0

# %%
def avg_len(doc_list):
    sum=0
    for doc in doc_list:
        sum+=len(doc)
    
    return sum

# %%
def bm25(term_freq, doc_len, avg_doc_len, idf, k1=1.75, b=0.75):
    return idf * ((term_freq * (k1 + 1)) / (term_freq + k1 * (1 - b + b * (doc_len / avg_doc_len))))

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/calebwentworth/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
parser = ArgumentParser()
parser.add_argument('-i', '--input', required=True, help='search domain file e.g. Answers.json',default="Answers.json")
parser.add_argument('-q', '--query', required=True, help='query source files e.g. topics_1.json',default="topics_1.json")
parser.add_argument('-e', '--eval', required=False, help='qrel evaluation file (optional)')

args = parser.parse_args()
input_file = args.input
query_file = args.query
eval_file = args.eval

with open(input_file,'r') as file:
    answers = json.load(file)

with open(query_file,'r') as file:
    querys = json.load(file)
# Out:
# usage: ipykernel_launcher.py [-h] -i INPUT -q QUERY [-e EVAL]
# ipykernel_launcher.py: error: the following arguments are required: -i/--input, -q/--query
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /home/calebwentworth/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3450: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
input_file = "Answers.json"
query_file = "topics_2.json"

with open(input_file,'r') as file:
    answers = json.load(file)

with open(query_file,'r') as file:
    querys = json.load(file)

# %%
preprocess_answers(answers)
# Out:
# [{'Id': '3', 'Text': 'examples httpcontikicom', 'Score': '15'},
#  {'Id': '12',
#   'Text': 'cruises larger cruises often get close land comforts cruising big ships may regulated soon smaller ships often let get right onto land costs start least 5k for ultra cheap airborne you get fly antarctica ecological way see experience actually walking it also cheapest option',
#   'Score': '52'},
#  {'Id': '17',
#   'Text': 'then get country take cash periodically much case issues assume often may always able find cash machine depending are edit  since said us cant suggest best card get avoidminimise foreign transaction fees asking personal finance se site likely best bet finding card is',
#   'Score': '126'},
#  {'Id': '18', 'Text': 'i draw 23 goes', 'Score': '20'},
#  {'Id': '19', 'Text': 'they go far east poland bulgaria that', 'Score': '11'},
#  {'Id': '20', 'Text': 'httpseat61com', 'Score': '64'},
#  {'Id': '22', 'Text': '', 'Score': '11'},
#  {'Id': '23',
#   'Text': 'when using debitcredit card remember become broken simply stop working cash solve potential problem',
#   'Score': '16'},
#  {'Id': '24',
#   'Text': 'using debit card taking money atm needed another alternative although may limited atm network also fees usually dire dedicated exchanges from experience traveling first world country safe taking 20 cash incidentals filling rest debit withdrawals credit cards available finally aware debit card daily onetime withdrawal limits fees may well want withdraw max max low withdraw max day access cash may restricted calling bank also inquire limits see raised necessary',
#   'Score': '19'},
#  {'Id': '29',
#   'Text': 'for within europe vodafone currently pretty good vodafone passport means single charge answermake call rest uk rate 40month plan theyll give 25mbdaycountry data free 10 free texts day',
#   'Score': '9'},
#  {'Id': '32',
#   'Text': 'most airline alliances occasionally single airlines offer around world fares it cost effective especially premium class business first class fares flyertalk forum lot trip reports done rtw fares check trip reports forum for example flew new york berlin took train madrid flew madrid cairo three segments would used it matter fly not still takes away overall segment limit segment refers one specific flight',
#   'Score': '31'},
#  {'Id': '35',
#   'Text': 'if going remote place small island check online guidebooks see atms money common occurrence is bringing 100 external currency accept us dollars fiji example chilean pesos easter island ideally get country en route good backup try get currency advance justincase probably use it',
#   'Score': '104'},
#  {'Id': '36', 'Text': '', 'Score': '19'},
#  {'Id': '37',
#   'Text': 'by invitation people company russia think you stable way get visa for touristic trip voucher made travel agencies try choose popular one like нева тревел компани also cities stay three days without visa you think',
#   'Score': '12'},
#  {'Id': '38',
#   'Text': 'this listing get started httpwwwairtimetablecomairpass_north_americahtm',
#   'Score': '7'},
#  {'Id': '39',
#   'Text': 'its always fun learning new places figuring travel looking different travel forums also help well looking reviews different locations',
#   'Score': '5'},
#  {'Id': '40', 'Text': '', 'Score': '11'},
#  {'Id': '42',
#   'Text': 'httpwwwlonelyplanetcomthorntreeindexjspa',
#   'Score': '6'},
#  {'Id': '43', 'Text': '', 'Score': '7'},
#  {'Id': '44',
#   'Text': 'these days another good place look travel blogs handful dedicated sites heres review several httpwwwtravelfishorgfeature91  search name destination along blog bound run interesting  useful experiences',
#   'Score': '5'},
#  {'Id': '46', 'Text': '', 'Score': '13'},
#  {'Id': '48', 'Text': '', 'Score': '22'},
#  {'Id': '49', 'Text': '', 'Score': '16'},
#  {'Id': '50', 'Text': '', 'Score': '8'},
#  {'Id': '52',
#   'Text': 'hands best way people live area best knowledge area area long enough befriend someone guarantee see something expect see magazine',
#   'Score': '13'},
#  {'Id': '53',
#   'Text': 'distances inn argentina largeeven going way patagonia bus service excellent luxury buses reclining seats meal service plane flights also available expensive would recommend rental car local trips reached final destination',
#   'Score': '8'},
#  {'Id': '54', 'Text': 'enjoy trip', 'Score': '18'},
#  {'Id': '55', 'Text': 'see httplinnamuuseumeekoken', 'Score': '5'},
#  {'Id': '56',
#   'Text': 'this blog post information middle might help you httpboardingareacomblogsonemileatatime20080503awardbookingquestion e update  only standard full awards available redemption flights allbusiness class a340500',
#   'Score': '8'},
#  {'Id': '57',
#   'Text': 'there may guides take deep jungle tourists do ive heard amazon jungle peru may rewarding wildlife perhaps remote personal experience',
#   'Score': '9'},
#  {'Id': '58',
#   'Text': 'you also visit patagonia  maybe small boat trip explore views',
#   'Score': '9'},
#  {'Id': '60',
#   'Text': 'it possible answer question way applies globally different conditions different countries',
#   'Score': '4'},
#  {'Id': '61', 'Text': '', 'Score': '4'},
#  {'Id': '62', 'Text': '', 'Score': '10'},
#  {'Id': '63', 'Text': '', 'Score': '7'},
#  {'Id': '64', 'Text': '', 'Score': '20'},
#  {'Id': '65',
#   'Text': 'youll generally problem private car services',
#   'Score': '6'},
#  {'Id': '68', 'Text': '', 'Score': '1'},
#  {'Id': '70', 'Text': '', 'Score': '0'},
#  {'Id': '71',
#   'Text': 'be aware countries such uk competitive pay go market cheap flexible sims available bundled data etc countries france lot less competitive',
#   'Score': '5'},
#  {'Id': '72', 'Text': 'i experience renting car sorry', 'Score': '8'},
#  {'Id': '74', 'Text': '', 'Score': '36'},
#  {'Id': '76',
#   'Text': 'for example looking exotic place go honeymoon going summer exotic places rainy season may want consider place able things even rain examples maldives one gorgeous places go nothing apart sand sea relaxation therefore raining ruin holiday case place like mauritius would good compromise goodlooking beaches also plenty activities',
#   'Score': '8'},
#  {'Id': '80',
#   'Text': 'i recommend aggregator sites httpwwwhipmunkcom also check budget airlines httpwwwryanaircom',
#   'Score': '1'},
#  {'Id': '82', 'Text': '', 'Score': '0'},
#  {'Id': '83', 'Text': '', 'Score': '5'},
#  {'Id': '87',
#   'Text': 'in strasbourg itself got quite museums visit may need leave one person outside small child worth climbing church tower view theres lots nice places see around old town foot',
#   'Score': '5'},
#  {'Id': '88',
#   'Text': 'in general prices go get closer departure date lower fare buckets sell out',
#   'Score': '7'},
#  {'Id': '90', 'Text': '', 'Score': '6'},
#  {'Id': '91',
#   'Text': 'essentially summary japan large unlikely travel plans tourist anywhere near accident',
#   'Score': '41'},
#  {'Id': '92',
#   'Text': 'often local tour operators cover filming locations nearby even offer specific halfday day tours remoteharder reach places theres anything lotrrelated see area always someone willing show you',
#   'Score': '13'},
#  {'Id': '94', 'Text': '', 'Score': '1'},
#  {'Id': '96',
#   'Text': 'we took bus took 45 minutes tel aviv jerusalem close together jerusalem much interesting tourist perspective ie rich history architecture',
#   'Score': '20'},
#  {'Id': '98',
#   'Text': 'im sure state insurance country take grain salt also expert insurance',
#   'Score': '6'},
#  {'Id': '101', 'Text': '', 'Score': '11'},
#  {'Id': '103',
#   'Text': 'if really concerned getting ripped unlikely would wait arrive ask recently returned travelers booked whether would recommend them may even get small discount say referred someone else similarly sapa tour operators recommend trekking withto meet local hmong tribes would also thoroughly recommend forget bring decent hiking boots or buy hanoi always muddy hike get boots cleaned dried 20 minutes dollar idea it',
#   'Score': '13'},
#  {'Id': '104',
#   'Text': 'if flexible dates trip optional flying popular route could try waiting chance catch sale keep mind later buy ticket later making reservations hotels rental cars could gone price finally bing travel feature analyzes airfare trends predicts whether buy wait better price works hightraffic usa domestic route',
#   'Score': '7'},
#  {'Id': '106', 'Text': '', 'Score': '21'},
#  {'Id': '107',
#   'Text': 'in retrospect seems like 20usd well spent bother paying places reputation',
#   'Score': '6'},
#  {'Id': '108',
#   'Text': 'you also take tour weta studios wellington really neat best free',
#   'Score': '13'},
#  {'Id': '109',
#   'Text': 'httpwwwgreyhoundcom httpmegabuscom httpswwwboltbuscom you also travel train in general bus routes cover country train see map amtrak network here long distance trains generally comfortable long distance buses long distance trains include overnight trips usually sleeping cars beds obviously affects price want private cabin bed going cost lot regular seat if good driver 25 might consider renting car costs renting one city returning another also fairly high however sometimes get special deals rental cars cheap company high number cars needs returned particular city',
#   'Score': '27'},
#  {'Id': '111',
#   'Text': 'ive heard couple different people permits tibet foreigners currently closed though probably well call agency the big places english speaking staff well see say hard find concrete information kinds things agencies usually date',
#   'Score': '13'},
#  {'Id': '112', 'Text': '', 'Score': '7'},
#  {'Id': '113', 'Text': '', 'Score': '8'},
#  {'Id': '114',
#   'Text': 'especially asian countries where travel experience easily pick sim cards shopping kiosks almost anywhere rates really cheap compared live new zealand',
#   'Score': '42'},
#  {'Id': '117', 'Text': '', 'Score': '4'},
#  {'Id': '120',
#   'Text': 'with find deal access 9 million searches performed every month websites order find best flights best offers found users one click general search criteria greater number arrival andor departure cities flexibility travel dates easier find lowcost flight',
#   'Score': '3'},
#  {'Id': '121', 'Text': 'for example', 'Score': '10'},
#  {'Id': '124',
#   'Text': 'the us httptravelstategovtraveltravel_1744html the uk httpwwwfcogovukentravelandlivingabroadtraveladvicebycountry australia httpwwwsmartravellergovauzwcgiviewadvice france in french httpwwwdiplomatiegouvfrfrconseilsauxvoyageurs_909indexhtml germany in german httpwwwauswaertigesamtdedelaenderinformationensicherheitshinweiseazlaenderauswahlseite_nodehtml',
#   'Score': '26'},
#  {'Id': '125', 'Text': '', 'Score': '3'},
#  {'Id': '126',
#   'Text': 'standard premier eurostar pretty much same except get small cold dish cold alcoholic nonalcoholic beverage whether worth you choice eurostar standard premier tgv first class choice eurostar standard standard premier note carriages 5  14 power sockets eurostar book seat one buy nice meal ms take train difference comes difference seat size',
#   'Score': '16'},
#  {'Id': '130',
#   'Text': 'i geiger counter hearing local news tokyo seems quite safe you might want avoid fukushima area even though going day two ok',
#   'Score': '19'},
#  {'Id': '131',
#   'Text': 'the weather warm not hot  less italy japan see minimummaximum graph nice in celsius 25c77f during summer touristic places open everywhere even south warmer better most festivals happen summer especially countryside ones  list ',
#   'Score': '15'},
#  {'Id': '133',
#   'Text': 'id say likely get sailing adventure cruise cargo ship earn keep sailing yacht working crew member many good sites finding yachts including httpwwwcrewfilecom as luck would it wondered larger ship top picture jamestown harbour was turns rms st helena  royal mail postal ship ride passenger cape town south africa st helena looks trafficked way getting tourist look expensive either a couple thousand pounds rather 15000 euros note prices gbp anyone wanting visit st helena quickly  cheaply  less seasickness note also building airport ',
#   'Score': '3'},
#  {'Id': '134',
#   'Text': 'we used banks usa give debit check card magnetic stripe credit cards way credit cards chip almost none require pin used credit card most european stores accept us credit cards able buy food grocery etc using usa credit cards now defunct travelex cash passport chipandpin protected good idea costs lot load small increments charge 14 read enlightening thread started joel spolsky ',
#   'Score': '32'},
#  {'Id': '137',
#   'Text': 'the rule respect would ignore anyone asking money  conversation going lead anywhere',
#   'Score': '83'},
#  {'Id': '139',
#   'Text': 'this mean wear one naff money belts id credit cards drivers license secure necessary theyre walking around  take cash need you leave everything else place staying get robbed pickpocketed loss minimized consider keeping copy passport page times case robbed stolen luggage',
#   'Score': '6'},
#  {'Id': '140',
#   'Text': 'your guides boil water you need chemically treat water give you however unsure water get free additional purification mec mountain equipment coop nice article water purification here refined search water purification product',
#   'Score': '10'},
#  {'Id': '141',
#   'Text': 'there high risk piracy coastal areas yemen attacks pirates forms shipping around yemens waters gulf aden pirates using motherships attack shipping 1000 nautical miles 1850km coast somalia all forms shipping attractive targets somali pirates including commercial vessels pleasure craft yachts etc luxury cruise liners maintain high level vigilance exercise extreme caution anywhere near waters according international maritime bureaus imb piracy reporting centre prc 217 attempted attacks piracy 47 vessels hijacked 867 crewmembers taken hostage gulf aden east coast somalia 2009',
#   'Score': '17'},
#  {'Id': '142',
#   'Text': 'know fill  gas huge difference state state  province province just expensive not make best fun if know people done track ask liked stopped walmarts good places get snacks nap bring a lot music map route using rough estimates fill every x kms sleep b eat c etc expect follow dot find fun road trip randomness unpredictability trip ensure budget every plan break down safety cash numerous times road trips where something fun happened',
#   'Score': '3'},
#  {'Id': '146',
#   'Text': 'i avoid money belts easy spot someone asks lift shirt actually loop stitched inside pants attach small pouch passport extra money second big three recognized experienced travellers',
#   'Score': '3'},
#  {'Id': '147',
#   'Text': 'i went solo really know russian aside form picked there stayed europe side urals bounced hostels definitely difficult go solo pedimiming patience easy enough contrary lot stereotypes russians generally nice helpful people cant tell many pairs nit socks bought babushkas streets i do course always recommend studying culture language bit go know words carry dictionary where isbathroompoliceembassy i wantfoodwaterbeer set words pretty much required ever go',
#   'Score': '27'},
#  {'Id': '149', 'Text': '', 'Score': '5'},
#  {'Id': '150',
#   'Text': 'if google international sim see tons websites selling payasyougo sims many countries easy purchase arrival airport know exactly looking for',
#   'Score': '17'},
#  {'Id': '151',
#   'Text': 'the best rates often rates get american credit card debit card  try charge much can fees low exchange rates fair however many american banks charge several dollars every foreign currency transaction plan spend lot time europe may want apply credit card low free foreign currency transactions  right now capital one reputation best deal foreign currency my second favorite strategy get cash foreign atms using banks debit card attached checking account  ive never problem this heard pin 4 digits may work internationally countries atms like american bank cards notoriously japan japan find post office atms happy accept american bank cards any kind transaction involves human standing behind counter changing money going bloody expensive like 15 expensive more pay person counter rarely this very rarely europe find dealing automatic machine accepts credit cards keeps asking pin refusing read american credit card  common places ive happen automatic ticket machines railroad stations bicycle rental machines unattended gas stations toll booths france essentially whats happening european credit cards embedded chip require pin american credit cards use magnetic stripe in situations europe must pay chip pin credit card  see this question information getting chip pin card american evidence chip pin cards widely available us bankcard holders fall 2015  in pinch discover nicer hotels often happy convert money you  rates good keep hundred dollars us cash hidden away somewhere safe itll get kind situation',
#   'Score': '47'},
#  {'Id': '152', 'Text': '', 'Score': '16'},
#  {'Id': '156',
#   'Text': 'this also bonus giving spanish number duration trip people spain call sensible amount money',
#   'Score': '6'},
#  {'Id': '160', 'Text': '', 'Score': '5'},
#  {'Id': '161',
#   'Text': 'and try remember hiking camping dangerous people actually nice india thailand safe',
#   'Score': '7'},
#  {'Id': '162', 'Text': '', 'Score': '9'},
#  {'Id': '168',
#   'Text': 'however cheaper option time spare arrive november start season many boats full such often offer 50 prices trips antarctica still expensive massive saving',
#   'Score': '33'},
#  {'Id': '169', 'Text': '', 'Score': '11'},
#  {'Id': '171',
#   'Text': 'a friend cycled london new zealand 20 months cycling places like iran afghanistan india  hard countries scary again fine scares sure general made amazing stories another friend who im currently chasing uzbekistan hes riding 85cc scooter london mongolia hes crashed broken down lost parts  people welded scooter together nothing hunted spare parts him always refused take money  theyre happy help goodness hearts dont scared cautious fantastic world  scary exciting go explore it',
#   'Score': '16'},
#  {'Id': '172',
#   'Text': 'another sneakier method depending need data fast needs be 3g kindle free data download books amazons whispernet almost every country world basic experimental web browser it bit effort ive managed get gmail google maps gtalk running  facebook twitter even mostly work',
#   'Score': '13'},
#  {'Id': '173',
#   'Text': 'however rovaniemi arctic circle easy get fly train helsinki overnight also home santa claus best times dark obviously theres new moon best bet  least light sky check first dates rovaniemi claims see auroras nights although course totally weather solar activity dependent  never guarantee it good luck',
#   'Score': '22'},
#  {'Id': '174',
#   'Text': 'one best suggestions write requests down example  trains write destination in cyrillic time numbers mostly universal class draw set bunks indicate top bunk almost words required clear im after',
#   'Score': '22'},
#  {'Id': '175',
#   'Text': 'note cusco likely travel puno first small mostly dull town two travel options quick bus route south la paz see link  go via copacobana bus take separate ferrie across time route sounds quite interesting fun',
#   'Score': '6'},
#  {'Id': '176', 'Text': '', 'Score': '6'},
#  {'Id': '177',
#   'Text': 'iv also told hitching totally fine quite common although try myself id prefer drive roads could quite  interesting',
#   'Score': '12'},
#  {'Id': '178',
#   'Text': 'suggested cities activities below as getting around bus easiest safest comfortable three major classes  semicama chairs tilt cama turns bed camasuite  unbelievable generally includes food ham cheese semicama goes champagne roasts camasuite quality depends bit company argentina fantastically comfortable even long distances have fun',
#   'Score': '20'},
#  {'Id': '179', 'Text': '', 'Score': '6'},
#  {'Id': '180', 'Text': '', 'Score': '9'},
#  {'Id': '181',
#   'Text': 'sometimes beggars quite insistent might even physically try hold back tugging shirt etc best way handle situation throw money it politelybutfirmly saying walking away',
#   'Score': '109'},
#  {'Id': '182',
#   'Text': 'httpwikitravelorgencopenhagen list best things see do personal experience two trips there tivoli themepark well worth visit oldschool touristtrappy disney universal right next central station easy get to the mermaid worth photo op  away display last year for fun take train across ocean malmo sweden doenst take long ride quite experience also foodie fantastic restaurants whether budget willing splurge top places',
#   'Score': '6'},
#  {'Id': '183',
#   'Text': 'i found method lot less tedious carry large amounts cash bothering whether travellers cheques accepted prepaid travel card available currency want best thing get usd travel card use withdraw cash get charged visas wholesale currency exchange rates plus 12 transaction fee depending bank',
#   'Score': '11'},
#  {'Id': '184', 'Text': '', 'Score': '6'},
#  {'Id': '187', 'Text': '', 'Score': '10'},
#  {'Id': '188',
#   'Text': 'if mind working always go somethign like wwoof  also working hostel usually pretty good gig free place live cash typically easily find work one walking asking',
#   'Score': '25'},
#  {'Id': '190', 'Text': '', 'Score': '10'},
#  {'Id': '191', 'Text': '', 'Score': '10'},
#  {'Id': '192',
#   'Text': 'write location united kingdom destination everywhere see cheapest destinations chosen time period all year see broadest list flight deals uk year other promotionaldeal opportunities include',
#   'Score': '11'},
#  {'Id': '194',
#   'Text': 'numbers 1 3 hello bye please thanks excuse mesorry also certainly helps get around find shopshotelsetc able read cyrillic lot international words same look differently experience getting head hard especially letters around time',
#   'Score': '15'},
#  {'Id': '195',
#   'Text': 'if weekend mind want travel head skyscannernets weekend planner shows cheapest flights anywhere dates choose however occasionally airline bonus special homepage sites like kayak pick up sometimes worth checking airlines themselves',
#   'Score': '12'},
#  {'Id': '196',
#   'Text': 'syria  jordan  egypt  sudan  ethiopia ',
#   'Score': '13'},
#  {'Id': '197', 'Text': '', 'Score': '4'},
#  {'Id': '198',
#   'Text': 'i used visa russia 2008 get tourist visa year 3 month double entry business visa times fantastic one point  booking train tickets outside far expensive booking countries themselves ive arrived volgograd 34 hours st petersburg booked 4 hours go theres really problem getting tickets either kupe platzkart classes thought itll save lot able flexible unless able get massive discount buying whole lot good luck fantastic experience',
#   'Score': '29'},
#  {'Id': '199',
#   'Text': 'the exception johannesburg car hijacked enroute suitcase never made airport  apparently last year luggage theft reduced 60 bodes well baggage pilfering 06 bags pass airport think still bad lock bags use bag wrapping machines available itll deter opportunistic thief',
#   'Score': '25'},
#  {'Id': '200',
#   'Text': 'i recently returned vietnam hotels stay hanoi tieups tour operators especially tours sapa ha long bay travel sapa hotel book us 1 night2 day ha long bay tour travelled cristina cruises vietnamese junk boats wonderful experience good time go cat ba island taken one biggest cave islands bay cruises offer variety options pick from',
#   'Score': '5'},
#  {'Id': '201',
#   'Text': 'the downside cannot book accommodation right away need communicate owners see works you would mean start search pretty early',
#   'Score': '9'},
#  {'Id': '202',
#   'Text': 'you buy weekly transpass septa use septa bus trolley',
#   'Score': '11'},
#  {'Id': '204',
#   'Text': 'rivoli castle  open tuethu 10am5pm frisun 10am9pm',
#   'Score': '6'},
#  {'Id': '207',
#   'Text': 'for example language barrier problem  polite smile people help you but never go deep city really know about  start 500m away hotel',
#   'Score': '55'},
#  {'Id': '208',
#   'Text': 'i prefer wikivoyage  date use books treats site often less visited still diamonds hidden rough failing that find local draw picture point belly hungry itll usually get laugh suggestion ',
#   'Score': '25'},
#  {'Id': '209',
#   'Text': 'and course  ask locals nothing beats local knowledge city aware course everyone knows much city  may need ask one  id also like add wikitravel  wiki nature  often date sources especially volatile areas used south america strikes on proved useful one occasion identify blocked roads  borders',
#   'Score': '6'},
#  {'Id': '212',
#   'Text': 'i think general find schedules us public transportation bit looser used uk at least limited experience london underground pickup times vary 15 minutes many cities without considered unusual especially bus lines philadelphia raj mentioned serviced septa good combination buses subways trains trains generally reliable provide fast easy access main parts city operating 3 main hubs within city provide access suburban areas subways provide good access throughout city areas immediately serviced trains buses provide access everywhere else although tend run less frequently particularly less popular destinations schedules more flexible new yorks subway excellent means travel within city',
#   'Score': '16'},
#  {'Id': '213',
#   'Text': 'httpwwwcargoshipvoyagescomviewallvoyagesregiontoshow2 a friend cycled london nz take cargo ship australia nz exactly cheap similarly friend looking boats south america nz again cheaper flying experience guess  time chilling nice quarters seeing great ocean ports stop at',
#   'Score': '7'},
#  {'Id': '214',
#   'Text': 'httpwwwinyourpocketcomestoniatallinntunnelsundertallinn_70029fmore1',
#   'Score': '10'},
#  {'Id': '215',
#   'Text': 'there couple caveats though i cant give first hand experience travelling area without using carnet used every border in cases refusing give money insisting take it also travelled ghana where believe carnet is required driving car the rac uk gave us carnet 200 wed pay insurance option security payment would cost extra 80 10 security 150 vehicle value 500insurance tax plus 350 deposit may misunderstood this seems pretty reasonable becomes better value countries drive through',
#   'Score': '9'},
#  {'Id': '216',
#   'Text': ' uzbekistan tashkent  telephone 998 71 12052789  fax 998 71 1205281  address 1 bol mirabadskaya 10 700090 tashkent you expect processing take 15 working days id ring consulate uzbekistan check requirements are problems new zealander unless journalist note need tell upfront planning bringing vehicle also need permit visit nature reservesborder zones also need letter invitation letter recommendation embassy list turkmen embassies abroad detailed info including areas need extra permits this page seems indicate want pick visa airport need arrange advance',
#   'Score': '11'},
#  {'Id': '219', 'Text': '', 'Score': '3'},
#  {'Id': '220',
#   'Text': 'in case trip goes jfkmle stops singapores hub sin however also short stopover frankfurt jfksin my guess book ticket airlines hub and may case sq changing planes hub upgrade portions separately',
#   'Score': '6'},
#  {'Id': '222',
#   'Text': 'ive never single problem xe regardless method used move money  draft wire ach bill payment online banking etc free pretty simple sign up online  besides standard info required upload scan bank statement in short would recommend joels answer unless bank account euros case use xe another service via ach eft no fee delay couple days money deposited could probably get account first visit depending particular countrys laws banks rules foreign account holders',
#   'Score': '10'},
#  {'Id': '223',
#   'Text': 'im going see ports caribbean run freight',
#   'Score': '5'},
#  {'Id': '224',
#   'Text': 'how works star alliance 2 generic levels status  star alliance gold star alliance silver particular airline status corresponds one two statuses what means that frequent flyer number entered reservations fly airlines star alliance see goldsilver give benefits accordingly lounge access priority boarding fast track also earn miles airline whenever fly star alliance member airline e wanted add technically ask status airlines if planning switch flying them contact ask status match give think high value passenger usually fly certain amount within certain number weeks retain status',
#   'Score': '16'},
#  {'Id': '225',
#   'Text': 'it also good idea check page mreclipse fred espenak hes solar eclipse veteran going place goes usually good idea',
#   'Score': '9'},
#  {'Id': '227', 'Text': '', 'Score': '8'},
#  {'Id': '228',
#   'Text': 'if find volunteer work near destination likely find travelers experience willing share volunteer work ive found type currency like time also host country nationals collaborate volunteers often excited share country someone devoted time cause organization',
#   'Score': '16'},
#  {'Id': '230',
#   'Text': 'teaching english foreign language efl another one may offer flights fairly decent pay often need qualification least experience',
#   'Score': '9'},
#  {'Id': '231',
#   'Text': 'personally either check guide book country im going they usually give helpful advice general section failing ask ive generally found staff helpful comes explaining tipping norms tourists even better ask friend country maybe local sat next busplanetrain',
#   'Score': '4'},
#  {'Id': '233',
#   'Text': 'if 100 cannot take carryon would suggest investing case made specifically cameras something like zero halliburton aluminum camera cases help protect rough handling',
#   'Score': '10'},
#  {'Id': '234',
#   'Text': 'httpwwwflyertalkcomforumtravelbuzz738653foreigntippingguidecountryregionhtml',
#   'Score': '11'},
#  {'Id': '237', 'Text': '', 'Score': '7'},
#  {'Id': '240', 'Text': '', 'Score': '16'},
#  {'Id': '241', 'Text': '', 'Score': '4'},
#  {'Id': '245',
#   'Text': 'los angeles built cars worst public transportation imaginable ever since general motors conspired eliminate citys trolley system  yes buses taxis find buses take forever and get stuck traffic taxis hard find expensive there plenty cities public transportation option new york chicago san francisco la one them',
#   'Score': '69'},
#  {'Id': '249', 'Text': '', 'Score': '7'},
#  {'Id': '251', 'Text': '', 'Score': '9'},
#  {'Id': '258',
#   'Text': 'just rehashing answer similar question ginamin',
#   'Score': '10'},
#  {'Id': '262', 'Text': '', 'Score': '18'},
#  {'Id': '263',
#   'Text': 'well said earlier la clearly made cars buses take freeways move rather slowly depends route agency also even metro primary agency area whole bus network la suburbs made lines belong many different agencies nearly every city agency instance long beach served long beach transit may find express buses run freeways routes luckily interesting spots hollywood well served transit walk fame subway stop right next it universal studios linked shuttle next stop line plan visiting amusement parks popular attractions disneyland knotts served metro bus downtown la check website metronet timetables want go six flags tricky would need take commuter train two buses reach park including long layover transit center therefore plan visiting lot different places get car beware traffic jams freeways especially i405 hopefully travelling alone allowed drive carpool lanes help go past singleoccupancy traffic',
#   'Score': '35'},
#  {'Id': '264',
#   'Text': 'the subway awesome  unlike dc get wherever want fare calculated entrance exit stops manhattan within easy walking distance stop need use bus anyway philadelphias septa works great 1 unlike nyc stations blanket city want go somewhere slightly walking distance use bus line lived years ago relatively safe efficient',
#   'Score': '7'},
#  {'Id': '265', 'Text': '', 'Score': '9'},
#  {'Id': '266', 'Text': '', 'Score': '16'},
#  {'Id': '267', 'Text': 'copenhagen city bike website', 'Score': '14'},
#  {'Id': '268',
#   'Text': 'no really buy starter pistol you know kind used signal beginning race fifty bucks according tsa regulations case contains firearm inspected at time checkin  locked tracked transit means bag searched except direct supervision traced far carefully checked bags mean spending little extra time getting checked airport peace mind worth absolutely must check serious valuables starter pistols  carried checked baggage must unloaded packed locked hardsided container declared airline checkin read firearms  ammunition section  travelers must declare firearms ammunition parts airline ticket counter checkin process container must locked locked container defined one completely secures firearm accessed cases pulled open little effort cannot brought aboard aircraft federal regulations prohibit unlocked gun cases or cases broken locks aircraft tsa inspects firearm cases ticket counter travelers remain area designated aircraft operator tsa representative take key back container cleared transportation travelers present security officer must open container tsa airline make reasonable attempt contact owner contact made container placed aircraft',
#   'Score': '20'},
#  {'Id': '271',
#   'Text': 'even delays due problems end regulation requiring compensate you time due compensation bumped flight overbooking',
#   'Score': '22'},
#  {'Id': '273',
#   'Text': 'los angeles little public transportation cant depend get places likely want visit within reasonable amount time your best bet imo cash lasd greyhound ticket rent car use los angeles drive toaround san diego may pay little drop different city itll worth it',
#   'Score': '11'},
#  {'Id': '274',
#   'Text': 'there parts western states get via train theyre small percentage whole area if goal to instance get around sf bay area the combination bart muni caltrain  etc would sufficient',
#   'Score': '4'},
#  {'Id': '276',
#   'Text': 'plane company skat phone astrakhan 88512 39 03 62 88512 39 41 95 train astrakhan mangystau 20km aktau',
#   'Score': '4'},
#  {'Id': '278',
#   'Text': 'on subscription also authorise provider request 150 guarantee accountthis amount debited unless bike returned period 24 hours',
#   'Score': '12'},
#  {'Id': '279',
#   'Text': 'its possible pay coins must pay credit debit card casual user bike deposit reserved card day about 150  gets returned return bike back bordeaux grenoble marseille lot other cities use competing systemsnice also system userfriendly tourists calling number giving credit card number  also web interface available',
#   'Score': '11'},
#  {'Id': '282', 'Text': '', 'Score': '6'},
#  {'Id': '287', 'Text': '', 'Score': '3'},
#  {'Id': '288',
#   'Text': 'you buy daytickets 15 euro  weektickets 7 euro  yearsubscription 30 euro  you pay every station using bank card',
#   'Score': '13'},
#  {'Id': '290',
#   'Text': 'you cant cross georgian border south ossetia abkhazia territories  it criminal georgia  get problems there update if country agreement georgia novisa crossing such ukraine armenia on simply must follow rules bordercrossing russia georgia see official sites if need visa visit georgia it follow rules crossing borders  problems you cant get visa right border verchniy lars  get others official borders georgia there think cause problems peoples',
#   'Score': '14'},
#  {'Id': '296',
#   'Text': 'from httpwwwvisatorussiacomrussianvisansffaqnewhtml  which would seem imply yes georgia currently working there',
#   'Score': '8'},
#  {'Id': '297', 'Text': '', 'Score': '9'},
#  {'Id': '298', 'Text': 'have fun time europe', 'Score': '8'},
#  {'Id': '299',
#   'Text': 'it would seem no indicate could travel bulgaria',
#   'Score': '10'},
#  {'Id': '300', 'Text': '', 'Score': '15'},
#  {'Id': '302',
#   'Text': 'if hotel well situated going traveling major tourist attractions may well walking taking occasional taxi',
#   'Score': '11'},
#  {'Id': '303',
#   'Text': 'you book travel company licensed run tours often little expensive cheaper option get ask around find many local guides take up',
#   'Score': '9'},
#  {'Id': '304',
#   'Text': 'at least way arrive days clothing immediately need buy new',
#   'Score': '7'},
#  {'Id': '306', 'Text': 'buy couple bike locks put around wheel', 'Score': '4'},
#  {'Id': '307',
#   'Text': 'the chinatown buses run chinatown one city chinatown another mainly east coast thing spreading west coast these might use httpwwwchinatownbusorg  chinatown bus page',
#   'Score': '2'},
#  {'Id': '308', 'Text': 'so far good', 'Score': '5'},
#  {'Id': '330',
#   'Text': 'the main problem possible visiting nagornokarabakh republic crime azerbaijan illegal border crossing even nkr say word that  cant prove anything without words careful good luck',
#   'Score': '9'},
#  {'Id': '333', 'Text': '', 'Score': '11'},
#  {'Id': '338',
#   'Text': 'at time price sail pretty much flight region 300 usd',
#   'Score': '15'},
#  {'Id': '347',
#   'Text': 'with one exception who flew others gone via san blas islands which look simply stunning id seen several pictures hopping across florida shuttle launch which happen sigh id done  sounds like perfect stressfree break fun way get around the gap',
#   'Score': '23'},
#  {'Id': '351',
#   'Text': 'even know language people use use handy methods conversation  gestures images on recommend use books something  definitely understand people say misunderstanding',
#   'Score': '2'},
#  {'Id': '376', 'Text': '', 'Score': '12'},
#  {'Id': '377',
#   'Text': 'if plan use public transport lot buy akbil pass saves bit money need dig coins time  details ',
#   'Score': '17'},
#  {'Id': '379',
#   'Text': 'contiki tours also trips machu picchu  one trips cant vouch them contiki looks little expensive',
#   'Score': '7'},
#  {'Id': '380', 'Text': '', 'Score': '2'},
#  {'Id': '382',
#   'Text': 'the first step get cusco fly landing pretty spectacular get cheap bus pretty much anywhere else country people problems altitude cusco planning couple days acclimatisation exploring good idea short walks ruins near city help if want inca trail is recommended book well advance months popular popularity also well trafficked apparently charming enjoyable hike i it hearsay basically would prepare whinging tourists you salkantay  5days4nights goes high mountains 4600m past unclimbed snowcapped mountain called salkantay steep sections spectacular choquequirao  longer trek 9 days includes cultural immersion well spectacular scenery involves 2 days trekking back choquequirao path repeated views cordillera huayhuash leaves huaraz comparatively quiet route offering solitude scenery takes one two routes near cordillera blanca mountains lares  4days3nights takes quechuan lifestyle famous textile villages encountered along way crosses two peaks takes hot springs lakes jungle treks  involve short walk downhill onroad mountain biking bus machu picchu highly recommended like hiking diy hike  get aguas calientes train continue machu picchu either bus hiking fivemile trail get dawn opens views spoiled throngs tourists arrive later day other tips',
#   'Score': '17'},
#  {'Id': '383',
#   'Text': 'prefer coveredundergroundgaraged parking uncoveredlotstreet parking fewer people see motorcycle fewer people tempted make it thefts occur 11 pm 6 many people around welllit highvisibility parking lot deter seasoned criminal theres nobody around see him however careful park front access doors striped zones eg next handicap spaces near machinery granted bike perfectly safe impound lot',
#   'Score': '11'},
#  {'Id': '384',
#   'Text': 'for mechanical delays cancellations mx airline much higher obligation  usually rerouting airlines offering overnight accommodations fly enough earn status airline higher status greater likelihood getting something comped irops definitely ask flights partners or failing that airlines originating carrier usually loath send competitor sometimes happens be nice courteous agent although rough day fault really either gate agent harried find one another gate call airline number if trip wasted missed flight tell agent trip vain want go home may refund ticket price hub home least get fare difference back intl portion schedule time flights given onceaday faroff destination hours buffer thats super risky especially summer months thunderstorms etc usually try 34 hours minimum  check make sure theres least one flight flight intl departure case something happens first one for longer layovers get lounge pass one airlines much quieter calmer usually theres free food drink internet pass time sleep airport  check httpwwwsleepinginairportsnet  ive spent overnighters airports right actually get reasonable nights sleep ready 6am flight outta there',
#   'Score': '16'},
#  {'Id': '389',
#   'Text': 'their language indeed called icelandic fascinating regards history wikipedia with regards learning icelandic phrases anywhere people appreciate nonnative speakers making effort takk thanks easy one starters pronunciation nigh impossible english speakers exposed before think attain even basic grasp without lot study',
#   'Score': '58'},
#  {'Id': '393',
#   'Text': 'a large percentage travel budget spent cruise itself given includes lodging food and transportation appears heart set seeing particular part caribbean next important question is cruising style if like upscale aware cruise lines put best efforts longer cruises ive cruises ranging 414 nights experience and amenities pretty closely tracked trip length',
#   'Score': '7'},
#  {'Id': '396',
#   'Text': 'cdma found wide acceptance us licensing issues primarily major networks running verizon sprint check operator if runs cdma network theres good chance country travelling networks running standard even roaming agreements could lacking having said that most modern phones support multiple gsm frequency bands  phone technical specification says triband quadband good four ranges use least one region covered',
#   'Score': '14'},
#  {'Id': '397',
#   'Text': 'it true beggars part organised begging rings instead money maybe ensure child gets one square meal day really much child go hungry walk away feeling good i would say unsafe give country always good cautious',
#   'Score': '18'},
#  {'Id': '399',
#   'Text': 'of course travel guide dictionary may help there',
#   'Score': '17'},
#  {'Id': '400',
#   'Text': 'learn say do speak english  parlezvous anglais hablas inglés learn basic pronunciations two languages they may letters always sound same reading guide listening examples online help this bring common phrase book pocket dictionary learn hello please thank etc generally start words frenchspanish know switch phrase book as soon get stuck ask in language speak english see above at point usually switch english theyll appreciate tried if not point items phrase book and get dictionary problem words most commonly find dishes ingredients restaurants',
#   'Score': '24'},
#  {'Id': '404',
#   'Text': 'my wife booked roundtrip iadnrt ana using miles used miles upgrade outgoing flight return flight arrived japan decided also wanted upgrade return flight all however ana refused claiming flights cannot upgraded first leg itinerary flown even willing pay cash believe due fact underlying ticket purchased using miles way perform upgrade purchase full fare ticket thereby lose miles spent return flight',
#   'Score': '5'},
#  {'Id': '406',
#   'Text': 'as uk starting pounds bit specific first up probably want using uk debit card almost high fees think couple quid plus several  per withdrawl several cards used free eg nationwide charge beware secondly changing cash go there unlikely get great deal  spread difference buying selling rates almost always quite large eats rate thats commission the current advice june 2011 unchanged year get halifax clarity card proactive paying off they apparently object leave credit card overseas fees cash withdrawl fees but interest start accruing use take cash want it',
#   'Score': '7'},
#  {'Id': '408', 'Text': '', 'Score': '7'},
#  {'Id': '409', 'Text': '', 'Score': '7'},
#  {'Id': '410',
#   'Text': 'you remove shoes men trousers shorts women long skirt or trousers women shoulder arms cannot exposed women scarf sometimes',
#   'Score': '23'},
#  {'Id': '411',
#   'Text': 'the seller wanted haggle english the person actually spoke one 100 languages india or likely i completely butchered pronunciation',
#   'Score': '12'},
#  {'Id': '414',
#   'Text': 'school started less family vacations college kids looking cruises the worry hurricanes puts people off lack vacations labor day thanksgiving keep mind places like cruises alaska around certain times year theres time year cheaper others',
#   'Score': '9'},
#  {'Id': '416', 'Text': 'excerpt i add info time research', 'Score': '5'},
#  {'Id': '418', 'Text': '', 'Score': '5'},
#  {'Id': '419', 'Text': '', 'Score': '9'},
#  {'Id': '420', 'Text': '', 'Score': '4'},
#  {'Id': '421',
#   'Text': 'hindi useful primarily north western regions india people lot friendly even speak basic hindi phrases less inclined rip off said that correct pronunciation hindi tough master sort like learning chinese  get tones right understand chinese means hindi tonal language per se elements tone stress play part unlike english now southern parts india  bangalore instance mention itinerary  find less people capable speaking understanding hindi addition regional language state english de facto second language fact speaking hindi sometimes taken insult southern states seen north india imposing alien language upon them',
#   'Score': '59'},
#  {'Id': '424',
#   'Text': 'those basics welcoming mosque tourists depends usually many tourists visit place frequented ones often robes give free cover up case clothing deemed inappropriate smaller andor less frequented mosques may provisions',
#   'Score': '15'},
#  {'Id': '425',
#   'Text': 'think one nonparis thing like focus on build trip around that think find super memorable sure look loire  sure liked it',
#   'Score': '10'},
#  {'Id': '427',
#   'Text': 'the complete list cbp preclearance locations',
#   'Score': '15'},
#  {'Id': '430',
#   'Text': 'if us license this uk site handy tips driving spain rules etc terms international driving permit this site says us drivers technically need one spain always enforced though ive seen places say varies depending state issues license probably safest get one leave see travelstategov details get one american',
#   'Score': '4'},
#  {'Id': '431', 'Text': 'uk france australia usa', 'Score': '5'},
#  {'Id': '433', 'Text': '', 'Score': '6'},
#  {'Id': '434', 'Text': '', 'Score': '5'},
#  {'Id': '437',
#   'Text': 'there generally two reasons book trips cruise line theres one reason go cruise line tours one nicest parts cruising instant community arises fun hanging people ship too',
#   'Score': '3'},
#  {'Id': '439', 'Text': '', 'Score': '7'},
#  {'Id': '440',
#   'Text': 'hindi work everywhere seems even respected parts country ie india primary language found people helpful trying teach basic hindi phrases opposite found everywhere else ive travelled put areas different primary language bit like asking somebody slovenia romania teach russian if learn one word india make namaste  worked every part country went key turning locals rudely elbowing front train booking window kindly helping fill forms single word seems show local people another ignorant outsider',
#   'Score': '31'},
#  {'Id': '443',
#   'Text': 'if want stay longer need get temporary registration police may painful registration bound place live made host hotel know whether not summary staying less 3 months problem ticket 3 months is problem need solve host hotel or perform hack',
#   'Score': '13'},
#  {'Id': '445',
#   'Text': 'with warm start gps already knows ephemeris data least 3 satellites it therefore kick straight solving time signal equations get fix quickly that ephemeris data could either come recently used gps eg previous 46 hours could come network assisted gps more informations here here ',
#   'Score': '12'},
#  {'Id': '446',
#   'Text': 'for visiting australia example either need license english idp translates it theres much narrower list countries getting australian license require test see here details things for get idp australian see smart traveller ',
#   'Score': '41'},
#  {'Id': '449',
#   'Text': 'before go somewhere wifi browse around area ill visiting phone downloads maps im there navigate around without needing download anything using cached maps gps also browse around surrounding area too handy planning orientation',
#   'Score': '8'},
#  {'Id': '451',
# ...
#   'Score': '16'},
#  {'Id': '1851',
#   'Text': 'i mean planning every detail hotel booking place exact dates moving one place other be open mates opinions make compromises even choose make separate subtrips meet days after opens opportunity chat experienced alone',
#   'Score': '11'},
#  {'Id': '1852',
#   'Text': 'dont spend every waking moment together maybe means one modern art gallery visits ancient history museum maybe go round gallery different speeds meet cafe end make sure roughly agree expected costs comfort levels advance be prepared compromise sometimes go little your comfort zone something friend really wants to be honest something work out',
#   'Score': '18'},
#  {'Id': '1853',
#   'Text': 'for people actually travelling lot places around world seem make much sense booking trip nyc australia via dubai would around 2500 rtw trip vs 1300 normal trip',
#   'Score': '12'},
#  {'Id': '1854', 'Text': '', 'Score': '7'},
#  {'Id': '1855',
#   'Text': 'i felt suffocated every time sat inside car keeping window cracked open helped not eating meals right travelling could mints not gum chewy mints though used get motion sickness would get vile taste mouth often led vomitting mints helped reason',
#   'Score': '4'},
#  {'Id': '1857',
#   'Text': 'bulgaria  greece for macedonia albania could find general western balkans quote',
#   'Score': '11'},
#  {'Id': '1859',
#   'Text': 'the method messaging people individually yes see thats problem simply state hitchhiking sometime x x days give phone number ask text host',
#   'Score': '13'},
#  {'Id': '1861',
#   'Text': 'it says buses greece macedonia lot running anymore still able find some',
#   'Score': '2'},
#  {'Id': '1862',
#   'Text': 'as general rule big places east west coast visited certain ones inland in cases appropriate lines closed long distances trains normally slower equivalent european one run frequently for information geographical accuracy probably want seat61 map  official amtrak one give idea roughly travel amtrak map httpwwwzachshanercawpcontentuploads201003amtrakpocketmapjpg',
#   'Score': '29'},
#  {'Id': '1864', 'Text': '', 'Score': '5'},
#  {'Id': '1865',
#   'Text': 'i recommend technorama winterthur switzerland technology museum various experiments suited children also age groupes',
#   'Score': '2'},
#  {'Id': '1867', 'Text': 'in paris two them', 'Score': '4'},
#  {'Id': '1868',
#   'Text': 'no wouldnt last time ive checked online payments done via ideal  works dutch banks also really crappy solution pay online actually find physical terminal put credit card update seems improved lately many places foreign cards emv chip seem work netherlands safest way go one gvbs information centers  unfortunately means waiting queue very long queue case one near amsterdam centraal',
#   'Score': '10'},
#  {'Id': '1870',
#   'Text': 'niche brands like american express diners club commonly accepted bother international travel as visa vs visa electron mastercard vs maestro seen place would accept debit electronic ones credit cards hand places credit cards not debit cards accepted car rental hotel reservation etc',
#   'Score': '8'},
#  {'Id': '1871',
#   'Text': 'i see making sense north superior actually would love travelling oshawa montreal since train goes right past place would prefer get off know would never thing corridor route as well canada number places reachable train plane large boat  meaning train let there cant get all',
#   'Score': '26'},
#  {'Id': '1872', 'Text': '', 'Score': '13'},
#  {'Id': '1876',
#   'Text': 'the less expensive would take public minibuses thais use transport provinces minibuses catched victory monument go airport either take taxi about 200 baht take airport link phaya thai one rapid 100 baht think one stops every station phaya thai take bts victory monument one stop vans depart several places skytrain station near century mall normally 7am 8pm more infos  bangkok public transport map  getting hua hin',
#   'Score': '11'},
#  {'Id': '1877',
#   'Text': 'according question lot types documents showing intend return country origin ',
#   'Score': '8'},
#  {'Id': '1878', 'Text': '', 'Score': '3'},
#  {'Id': '1879',
#   'Text': 'i want add useful resource friend mine also used applying visa',
#   'Score': '4'},
#  {'Id': '1880',
#   'Text': 'at moment far cheapest way travel germany there two major web players mitfahrgelegenheiten market mitfahrgelegenheitde charge community members contact information available immediately publicly makes superior choice imo using mitfahrgelegenheit always 100 reliable business appointments usually made email phone sometimes people simply show  although naturally drivers usually do mitfahrgelegenheitde offering booking payment system allows reliable reservations vast majority rides still worked phone',
#   'Score': '7'},
#  {'Id': '1881',
#   'Text': 'germany indeed developing country far credit cards concerned things changing least amex visa mastercard  slowly supermarket chain rewe accepts credit cards most all stores may minimum purchase imposed local franchisee seen 5 10 amounts i never problems buying deutsche bahn train tickets various credit cards visa mastercard cannot testify cards issued countries accepted shouldnt problems turns may  see edit above as simon notes gas stations accept credit cards the vast majority hotels accepts credit cards',
#   'Score': '15'},
#  {'Id': '1882',
#   'Text': 'but sake completness want mention eurolines  coach company connects big cities whole europe personally used example travel tallinn st petersburg relatively cheap reliable comfortable coaches generally good form',
#   'Score': '3'},
#  {'Id': '1885',
#   'Text': 'httpwwwhauserexkursionendeamerikaeck12von_den_anden_zum_amazonasphp here another german site offers lot different tours ecuador necessarily trekking tours like hauser',
#   'Score': '3'},
#  {'Id': '1886',
#   'Text': 'its part international ticket or its special ticket issued civ protections for latter certainly uk least buy special tickets connecting international train journey going get eurostar get railsail train returning one get ticket tofrom special destination london international civ london eurostar civ tickets extend civ protection onto domestic leg also normally bonus valid peak time trains priced closer peak tickets bought possession onward international train ticket eg eurostar ticket dutch flyer railsail ticket see seat61 national rail details work uk if ticket think technically covered unless country gone whats required train companies often help same',
#   'Score': '5'},
#  {'Id': '1889',
#   'Text': 'according it several buses zadar split 3 hours ride unfortunately prices english version  last column carrier name',
#   'Score': '9'},
#  {'Id': '1890', 'Text': '', 'Score': '3'},
#  {'Id': '1891',
#   'Text': 'i personally drove years ago really recommend it',
#   'Score': '5'},
#  {'Id': '1892', 'Text': '', 'Score': '4'},
#  {'Id': '1893',
#   'Text': 'there buses  running approximately every halfhour saturday morning every hour later day journey takes 3 hours',
#   'Score': '5'},
#  {'Id': '1894',
#   'Text': 'in addition need serious storage offline google maps eventually settled navdroyd  android therell equivalents iphone etc cost dollars much  maps totally free download free open street maps maps vector graphics anyway fantastic interface little clunky took minutes get used to sorted brilliant  even siberia kyrgystan mongolia',
#   'Score': '12'},
#  {'Id': '1895',
#   'Text': 'httpwwwgapadventurescomtripsexploringtheamazonrainforestsel4d2011 gap adventures sole amazon tour ecuador search tours less 7 days 4 days duration takes quito coca jungle lodge back includes motorized canoe caiman hunting flashlight you look eyes  naturalist guide tell environment animals around',
#   'Score': '2'},
#  {'Id': '1896',
#   'Text': 'do unlocked phone need unlocked use another company gsm sim card buy cheap phone almost price sim card necessary it may expensive use outside us may want buy one sim card us another canada',
#   'Score': '3'},
#  {'Id': '1897',
#   'Text': 'mexico possibly countries require insurance underwriter country probably lot cheaper arrange trip you check state department travel advisories countries plan go through overly pessimistic sometimes give important information particularly recent criminal trends dangerous areas country despite doom gloom sounds like great trip  fun',
#   'Score': '7'},
#  {'Id': '1898',
#   'Text': 'train tickets transmongolian train available up 60 days departure day buy tickets far documents returned embassy train tickets refundable time departure but refund less 24 hours departure get fees that refund cost 5 euro in russian rubles update gagravarrs comment travel agency right  leave tech details pro',
#   'Score': '7'},
#  {'Id': '1900', 'Text': 'httpwwwvolunteersouthamericanet', 'Score': '7'},
#  {'Id': '1902',
#   'Text': 'i go  opted zanzibar instead do decide go zanzibar nungwi definitely touristy spot kendwa kilometers away quieter still enough keep occupied note say nungwi touristy mean 20 hotels lining beach  thats pretty much it soon step beach however local village',
#   'Score': '7'},
#  {'Id': '1903',
#   'Text': 'tldr  theres easy way determine whether card failed unless physically bentdamaged card failure big problem',
#   'Score': '12'},
#  {'Id': '1905',
#   'Text': 'from ferry page  then bit probably want schedule pdf lists dates theyre sailing next two months id suggest ring  email details end schedule ask departure timings days considering going',
#   'Score': '7'},
#  {'Id': '1906',
#   'Text': 'poti september 12 2011 ilyichevsk september 15 2011 geroi sevastopolyapoti september 12 2011 varna september 21 2011 geroi sevastopolyailyichevsk september 19 2011 varna september 21 2011 geroi sevastopolyailyichevsk september 19 2011 batumi september 26 2011 geroi sevastopolyavarna september 23 2011 batumi september 26 2011 geroi sevastopolya varna september 15 2011 batumi september 20 2011 geroi odessybatumi september 21 2011 varna september 28 2011 geroi odessyilyichevsk september 26 2011 varna september 28 2011 geroi odessyilyichevsk september 26 2011 batumi october 03 2011 geroi odessyvarna september 30 2011 batumi october 03 2011 geroi odessy',
#   'Score': '5'},
#  {'Id': '1907', 'Text': '', 'Score': '13'},
#  {'Id': '1908',
#   'Text': 'the us tricky one think insist rfid chipped passports entry country even backup plans',
#   'Score': '7'},
#  {'Id': '1909',
#   'Text': 'donate church auction coins form set country may interesting prize',
#   'Score': '9'},
#  {'Id': '1910',
#   'Text': 'its generally accepted fact scandinavian countries expensive places travel personally travelled lot within europe within scandinavia think much expensive comparison rest europe so short answer is yes  norway certainly significantly expensive european destinations general resembles switzerland regard which not say visit  some examples beer bar oslo set back much 10  80kr helsinki 46  normal considered expensive foreigners price dorm bed oslo hostel seems range 29 51   countries like germany france ive generally paid around 1525  edit  noticed norway guide wikitravel good section costs  quoting little bit update actual statistics a recent 2012 eurostat study prices goods services found eu zone average price level described 100 most expensive countries europe are  looking prices alcoholic beverages  tobacco only norway far away everyone else 250 followed iceland 155 uk 147 sweden 145 also food  nonalcoholic beverages norway expensive norway 164 switzerland 156 denmark 136 sweden 120 goes restaurants  hotels  norway 184 swizerland 157 denmark 154 sweden 147 words in things relevant traveller norway the expensive country europe  sources',
#   'Score': '22'},
#  {'Id': '1913',
#   'Text': 'since listed either live planning go cant give specific advice usually richer country is expensive money changing is places black market sometimes offer even better official exchange rates big currencies dodgy money changers corner give better rates banks official money changers theyre dodgy know numbers get scammed this course assumes definitely want phsyically change money fact really want know best way deal money issues travelling then gagravarrs answer deals general problem',
#   'Score': '12'},
#  {'Id': '1915',
#   'Text': 'other variant  use cellphone good vibrosignal way it noiseless quick way wake up',
#   'Score': '9'},
#  {'Id': '1916',
#   'Text': 'if going somewhere without access atms need take cash either currency change prechange destination one general tips firstly airports often give poor rate captive market expensive location next up make sure know real rate shop around aware commission free normally means worse rate they still want make profit normally makes sense small transactions large ones commission plus great rate often better get calculator check',
#   'Score': '19'},
#  {'Id': '1917', 'Text': 'dont phone silent vibrating alarm', 'Score': '15'},
#  {'Id': '1918', 'Text': '', 'Score': '12'},
#  {'Id': '1919',
#   'Text': 'looking bulgarian rail map  would seem likely train would pass plovdiv might worth going station ask otherwise could always nip sofia day taking overnight train there',
#   'Score': '7'},
#  {'Id': '1920',
#   'Text': 'keeping mind general tendencies exchange rates best worst the exception countries money fully freely interchangeable case often blackmarket exchange give much official ones banks however using blackmarket exposing fraud',
#   'Score': '25'},
#  {'Id': '1923', 'Text': '', 'Score': '7'},
#  {'Id': '1926',
#   'Text': 'to make worse geneva domicile lot big organizations like example un cern icrc who iao iso itu wipo wmo wosm wto unhcr thats living costs well accommodation costs exploding',
#   'Score': '14'},
#  {'Id': '1928',
#   'Text': 'if shops security check could problem take large amount fluid you',
#   'Score': '4'},
#  {'Id': '1929',
#   'Text': 'for flights liquids purchased security check taken onboard plane though so check rules specific destination origin go',
#   'Score': '19'},
#  {'Id': '1931',
#   'Text': 'fortunately getting one free usually pretty quick easiest way apply evisitor online  see eligible passport holders page check eligible evisitor more information australian visas found httpswwwhomeaffairsgovautravvisi',
#   'Score': '21'},
#  {'Id': '1935',
#   'Text': 'presuming doctor wants make sure plenty water  bring empty water bottle explain problem purser one flight attendants im sure shell glad fill bottle aircrafts fresh water supply concerned it get doctor write note letterhead stationery in case dutyfree sell water since theres duty due shops stands sell bottled water poster pointed out bringing water aboard may another question course airports institute second search passed security  one know of suvarnabhumi bkk bangkok',
#   'Score': '13'},
#  {'Id': '1936', 'Text': '', 'Score': '6'},
#  {'Id': '1937', 'Text': '', 'Score': '12'},
#  {'Id': '1938',
#   'Text': 'i think going big trip travel mate one also talk safety level traveler expects subjective safety vary heavily agree common safety range lead problem',
#   'Score': '5'},
#  {'Id': '1939',
#   'Text': 'as association flight attendants reasons ah theres rub problem or lackofproblem is turnedoff kindle generates exactly much electronic interference turnedon one say very little compared to say cellphone hugely less monitors use give safety instructions least planes eliminated crts might well jamming stations comes rf interference',
#   'Score': '9'},
#  {'Id': '1940',
#   'Text': 'my point unless going something involves walking dirt eg hiking time year would involve wading mud rain something minor interruption pleasant break day',
#   'Score': '5'},
#  {'Id': '1944', 'Text': '', 'Score': '7'},
#  {'Id': '1945',
#   'Text': 'if exchange money bank get much better rate try pay credit card whenever possible',
#   'Score': '23'},
#  {'Id': '1946',
#   'Text': 'its always good idea local currency hand matter going credit card also work though fees poor exchange rates depending card also intend use it call credit card company tell going trigger antifraud security check',
#   'Score': '12'},
#  ...]

# %%
doc_list = answer_reduce(answers)

# %%
corpus = generate_corpus(answers)
# Out:
# {'ovkaart', 'afternoonevening', 'charitable', 'rackandpinion', 'httpswwwcnncomtravelarticleilhadocardososaopaulobrazilindexhtml', '10gb', 'sokimex', 'flixbuses', 'recognisable', 'phibbs', 'upwere', 'bombay', 'adhere', 'frencheu', 'mutou', 'reykjavíkkeflavík', 'euus', 'locationprovided', 'bipaps', 'nepalbhutan', 'rùm', 'checksum', '44', 'assolutamente', 'treesurvey', 'apricale', '1115c', 'tbilisithe', 'travelit', 'holidays', 'desalinated', 'thei94', '50200', 'carportion', 'chile', '19dec16', 'tallinns', 'importance', 'favorably', 'cert2', 'tsim', 'wwwroutehappycomdo', 'bvisitors', 'pvd', 'daya', 'twentyone', 'auftanken', 'elliott', 'orconsulate', 'santarem', 'cheese', 'freiwillig', 'noticethats', 'stereo', 'fullspectrum', 'choster', 'figaró', 'downgrades', 'aquarantine', 'shears', 'rostocklaage', 'samothrace', 'specifications', 'turkeybalkan', '310317mshk', 'httpswwwdrive2dayde', 'moulins', 'daytsh', 'monopolies', 'incubators', 'aztec', 'slings', 'nouvelair', 'rno', 'roadsea', 'erp', 'gatwickconnects', 'melodramatic', 'unterlagen', '3never', 'appalling', 'guidesthe', 'http3vilascomwpcontentuploads201311palacioreidolixojpg', 'milesperhour', 'дня', 'marienbrücke', 'unfastened', 'wardens', 'cmutcd', '6000ers', 'genèveaéroport', 'bodiam', 'periodarrived', 'passengerscargo', 'kangerlussuaq', 'dispersed', 'bananas', 'dosuch', 'monarchy', 'intermediate_stationsappendcalling_pointstation_name', 'escluso', 'nanning', 'residenceemployment', 'allure', 'misheard', '68000', 'hanchinese', 'rope', 'lante', 'httpswwwmunichairportcomconnectingflights260553', 'edged', 'finlandalso', 'hinduja', 'httpwwwusatodaycomstorytodayinthesky20140206carryonweedasecurityriddleatcolowashairports5245917', 'rateon', 'inindonesia', 'nonrude', 'istanbulpanama', 'warning', 'boardingcheckin', '100200', 'bolets', 'starving', 'destinaiton', 'jetlite', 'montezumas', 'carthaginian', 'httpswwwvrsticketshopdeenoxidtagesticket1personhtml', 'shendi', 'աշխատավարձի', 'cotoneaster', 'roomrate', '171', 'pangi', 'brondesbury', 'mesto', 'אינו', 'bar', '1007400', 'indiscussions', 'httpswwwscotrailcouksitesdefaultfilesassetsdownload_ctsr1712_north_highlands_12205_webpdf', 'lakehurst', 'kaigasse', 'workinggenerating', 'paula', 'cureddried', 'seatguruorg', 'timor', 'benzinpreisde', 'haggled', 'baarlenassauhertog', 'transitting', 'sparpreisticket', 'buk', 'ravishing', 'detritus', 'bellagio', '2316', 'routeshanseatic', 'den', 'abhorrent', 'styding', 'stilllingering', 'doorway', 'protozoa', 'iodine', 'marcanteodaglia', 'hayfever', 'rezügen', 'httpswwwfacebookcomprecinct4posts5484281681604700', 'httpwwwmattatouillecom201007southwestchiefdiningcarfromlahtml', 'disturbs', 'httpwwwsitabusitensalernotoamalficoastbustimetable', 'httpswwwbusinessinsidercomwhyplanesdonotflyduringvolcaniceruption201711', 'japaneseoz', 'göschenen', 'ringbahn', 'youroyster', 'httpseurlexeuropaeuenlegalcontentsummaryvisacodehtml', 'sapica', 'mobikwik', 'blackmarket', 'vines', 'pcns', 'nominating', 'molestia', 'genuss', 'lieu', 'welcomes', 'bilboa', '1600hour', 'statemandated', 'vaccuum', 'httpsliverpoolairportzendeskcomhcenusarticles209487745ihaveaconnectingflightdoihavetogothroughsecurityagain', 'marsham', 'roya', 'httpswwwetiasvisacometiasnewsetiasgibraltar', 'pasific', 'breakdowns', 'psta', 'bollnästorget', 'marín', 'etou', 'zazenkai', 'aporpo', 'muse', 'douane', 'suburbsdormitory', 'migratoria', '00001', 'gloria', 'raffle', 'quantifiable', 'parisjohannasburg', 'tactics', 'mayen', 'arabian', 'gzip', 'puerta', 'tripit', 'niceties', 'differentials', 'spanglish', 'vincis', '5964', 'employerinviter', 'gurdwara', 'httphitchhikershandbookcom20150630traveliniranindependentlybritishamericancanadian', 'apertura', 'yhzyyzlhr', 'bussing', 'narcotics', 'httpexpertvagabondcomtravelinsurancetips', '๒๐', 'thiw', 'snake', 'vibrant', 'palatine', 'nasa', 'dov', 'fuzz', 'examiner', 'cabinelite', 'httpwwwinterraileu', 'のぞみひかりみずほさくらつばめ', 'пригородном', 'copious', 'caldo', 'subwaytobus', 'schengenvisainfo', 'altotasso', 'firenzebolo ...

# %%
def bm_search(query, index, doc_list, idf_values, k1=1.75, b=0.75):
    query_terms = query.split()
    scores = defaultdict(float)
    avg_doc_len = sum(len(doc) for doc in doc_list.values()) / len(doc_list)
    
    for term in query_terms:
        if term in index:
            idf = idf_values[term]
            for doc_id in index[term]:
                doc = doc_list[doc_id]
                term_freq = doc.count(term)
                doc_len = len(doc)
                scores[doc_id] += bm25(term_freq, doc_len, avg_doc_len, idf, k1, b)
    
    return sorted(scores.items(), key=lambda item: item[1], reverse=True)

# %%
def precompute_idf(index, num_docs):
    idf = {}
    for term, doc_ids in index.items():
        df = len(doc_ids)
        idf[term] = math.log((num_docs - df + 0.5) / (df + 0.5) + 1)
    return idf

# %%
def tf_search(query, index, doc_list, idf_values):
    query_terms = query.split()
    scores = defaultdict(float)
    
    for doc_id, doc in doc_list.items():
        score = sum(tf(term, doc) * idf_values[term] for term in query_terms if term in index)
        scores[doc_id] = score
    
    return sorted(scores.items(), key=lambda item: item[1], reverse=True)

# %%
index = index_answers(corpus,doc_list)

idf_vals = precompute_idf(index,len(doc_list))

# %%
#test
#print(bm_search("Big cruises are fun ",index,doc_list, idf_vals))
#print(tf_search("Big cruises are fun",index,doc_list))

# %%
def parse_query(query_dict):
    stop_words = stopwords.words('english')
    querys = {}
    for item in query_dict:
        id = item['Id']
        title = item['Title']
        body = item['Body']

        title = remove_stopwords(title,stop_words)
        
        title = title.lower()
        title = remove_tags(BeautifulSoup(title, "html.parser"))
        title = re.sub(r'[^\w\s]', '',title)
        
        body = remove_stopwords(body,stop_words)
        body = body.lower()
        body = remove_tags(BeautifulSoup(body, "html.parser"))
        body = re.sub(r'[^\w\s]', '',body)
        
        text = title+' '+body
        querys[id] = text

    return querys

# %%
def process_query(query_id, query_text, index, doc_list, idf_vals):
    bm_search_results = bm_search(query_text, index, doc_list, idf_vals)
    tf_search_results = tf_search(query_text, index, doc_list, idf_vals)
    
    bm_search_results_top5 = bm_search_results[:5]
    tf_search_results_top5 = tf_search_results[:5]
    
    bm_ranked = {doc_id: rank for rank, (doc_id, _) in enumerate(bm_search_results_top5, start=1)}
    tf_ranked = {doc_id: rank for rank, (doc_id, _) in enumerate(tf_search_results_top5, start=1)}
    
    return query_id, bm_ranked, tf_ranked

# %%
def run_querys(querys, idf_vals, index, doc_list):
    bm_results = []
    tf_results = []
    
    with ThreadPoolExecutor() as executor:
        futures = [
            executor.submit(process_query, query_id, query_text, index, doc_list, idf_vals)
            for query_id, query_text in querys.items()
        ]
        
        for future in tqdm(as_completed(futures), total=len(futures), desc="Processing Queries"):
            query_id, bm_ranked, tf_ranked = future.result()
            bm_results.append({query_id: bm_ranked})
            tf_results.append({query_id: tf_ranked})
    
    return bm_results, tf_results

# %%
q_input = parse_query(querys)
# Out:
# /home/calebwentworth/.local/lib/python3.10/site-packages/bs4/__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
result = run_querys(q_input,idf_vals,index,doc_list)
# Out:
# Processing Queries: 100%|██████████| 294/294 [07:41<00:00,  1.57s/it]

# %%
def result_gen(results,f_name):
    bm_result = results[0]
    tf_result = results[1]
    print(bm_result)
    q0="Q0"
    run_name = 'Caleb'
    bm_output = f_name.rsplit('.', 1)[0] +'_bm25'+'.tsv'
    tf_output = f_name.rsplit('.', 1)[0] +'_tf'+'.tsv'

    # tsv format: query_id "Q0" answer_id 0 rank run_name
    with open(bm_output, 'w') as f:
        for result in bm_result:
            query_id = list(result.keys())[0]
            for answer_id, rank in result[query_id].items():
                f.write(f"{query_id}\t{q0}\t{answer_id}\t0\t{rank}\t{run_name}\n")

    with open(tf_output, 'w') as f:
        for result in tf_result:
            query_id = list(result.keys())[0]
            for answer_id, rank in result[query_id].items():
                f.write(f"{query_id}\t{q0}\t{answer_id}\t0\t{rank}\t{run_name}\n")

# %%
result_gen(result,query_file)
# Out:
# [{'6': {'124182': 1, '34820': 2, '2943': 3, '89898': 4, '4684': 5}}, {'26117': {'122872': 1, '154554': 2, '177066': 3, '103669': 4, '84597': 5}}, {'7180': {'37930': 1, '120285': 2, '142943': 3, '5877': 4, '119473': 5}}, {'515': {'6184': 1, '86246': 2, '6185': 3, '8108': 4, '526': 5}}, {'1033': {'3637': 1, '46926': 2, '4945': 3, '124182': 4, '95796': 5}}, {'4634': {'44065': 1, '91463': 2, '6943': 3, '91802': 4, '149628': 5}}, {'151055': {'141165': 1, '151073': 2, '9772': 3, '93156': 4, '180775': 5}}, {'5149': {'5860': 1, '154554': 2, '21786': 3, '78876': 4, '175385': 5}}, {'185386': {'127135': 1, '180519': 2, '99358': 3, '73264': 4, '149646': 5}}, {'155155': {'18057': 1, '81905': 2, '163119': 3, '83933': 4, '20787': 5}}, {'27': {'113824': 1, '18109': 2, '168010': 3, '90180': 4, '158626': 5}}, {'42540': {'168111': 1, '42543': 2, '1681': 3, '37086': 4, '188089': 5}}, {'48649': {'16376': 1, '143433': 2, '7015': 3, '46738': 4, '161252': 5}}, {'186406': {'159259': 1, '173891': 2, '95364': 3, '180896': 4, '156753': 5}}, {'128516': {'128525': 1, '128549': 2, '18182': 3, '185076': 4, '27737': 5}}, {'103464': {'173891': 1, '47456': 2, '148457': 3, '178701': 4, '2978': 5}}, {'56343': {'157967': 1, '180519': 2, '103769': 3, '77460': 4, '80057': 5}}, {'27693': {'37930': 1, '113824': 2, '120285': 3, '142943': 4, '123514': 5}}, {'113157': {'175693': 1, '52664': 2, '57159': 3, '169533': 4, '67426': 5}}, {'47625': {'120379': 1, '60185': 2, '184049': 3, '73751': 4, '73771': 5}}, {'163375': {'131167': 1, '57373': 2, '123724': 3, '152635': 4, '178243': 5}}, {'177203': {'66129': 1, '138063': 2, '81608': 3, '83936': 4, '115816': 5}}, {'111146': {'157198': 1, '113824': 2, '46668': 3, '37120': 4, '66317': 5}}, {'51259': {'134273': 1, '149873': 2, '177523': 3, '60185': 4, '49283': 5}}, {'61984': {'66129': 1, '1683': 2, '153802': 3, '62022': 4, '31652': 5}}, {'123447': {'161999': 1, '52101': 2, '74709': 3, '147625': 4, '3517': 5}}, {'46093': {'81906': 1, '126499': 2, '7451': 3, '169164': 4, '173053': 5}}, {'2624': {'154554': 1, '116854': 2, '24870': 3, '13433': 4, '76309': 5}}, {'52781': {'181585': 1, '19577': 2, '8034': 3, '143686': 4, '23736': 5}}, {'30247': {'3902': 1, '10944': 2, '3611': 3, '17106': 4, '37930': 5}}, {'80936': {'71022': 1, '79747': 2, '141165': 3, '119057': 4, '126891': 5}}, {'23607': {'158407': 1, '62412': 2, '142991': 3, '7437': 4, '8545': 5}}, {'86545': {'141094': 1, '61809': 2, '93025': 3, '52394': 4, '96571': 5}}, {'110666': {'111285': 1, '120833': 2, '118634': 3, '27753': 4, '147879': 5}}, {'168993': {'158090': 1, '61139': 2, '68496': 3, '140517': 4, '164012': 5}}, {'1596': {'91463': 1, '81809': 2, '13963': 3, '91904': 4, '18178': 5}}, {'90165': {'127055': 1, '42899': 2, '64230': 3, '73715': 4, '180519': 5}}, {'76362': {'113824': 1, '48006': 2, '157560': 3, '184298': 4, '72386': 5}}, {'3666': {'147856': 1, '158792': 2, '154554': 3, '172608': 4, '132281': 5}}, {'27183': {'28895': 1, '30640': 2, '141094': 3, '27343': 4, '45794': 5}}, {'111112': {'130038': 1, '42131': 2, '24712': 3, '122614': 4, '96571': 5}}, {'2044': {'74871': 1, '514': 2, '178485': 3, '11326': 4, '93685': 5}}, {'51286': {'89089': 1, '23174': 2, '31493': 3, '37117': 4, '27336': 5}}, {'71245': {'8137': 1, '71257': 2, '83479': 3, '50305': 4, '177066': 5}}, {'131661': {'27737': 1, '92101': 2, '188104': 3, '91290': 4, '128525': 5}}, {'69711': {'5602': 1, '119057': 2, '71023': 3, '180603': 4, '41760': 5}}, {'21568': {'45160': 1, '49930': 2, '159526': 3, '185520': 4, '122872': 5}}, {'17984': {'33711': 1, '3902': 2, '37930': 3, '23364': 4, '19781': 5}}, {'68201': {'157162': 1, '145257': 2, '181649': 3, '169653': 4, '122872': 5}}, {'102463': {'96571': 1, '113824': 2, '119473': 3, '50069': 4, '163777': 5}}, {'74315': {'18057': 1, '163119': 2, '72386': 3, '168816': 4, '111243': 5}}, {'4675': {'148468': 1, '154554': 2, '185697': 3, '13963': 4, '4678': 5}}, {'10819': {'7758': 1, '158914': 2, '98182': 3, '158092': 4, '95995': 5}}, {'124010': {'34970': 1, '66344': 2, '60185': ...
